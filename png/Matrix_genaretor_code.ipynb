# %% [markdown]
# <a href="https://colab.research.google.com/github/farshid101/Thesis-2024/blob/main/png/Matrix_genaretor_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Example confusion matrix data
confusion_matrix = np.array([
    [127, 30, 26],
    [37, 91, 37],
    [32, 19, 174]
])

# Normalizing the confusion matrix
confusion_matrix_normalized = confusion_matrix / confusion_matrix.sum(axis=1)[:, np.newaxis]

# Labels for the axes
labels = ['positive', 'neutral', 'negative']

# Plotting the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_matrix_normalized, annot=True, fmt=".2f", cmap="Blues", xticklabels=labels, yticklabels=labels)

# Adding titles and labels
plt.title("Confusion Matrix")
plt.xlabel("Predicted Sign")
plt.ylabel("True Sign")

# Save the figure
plt.savefig("FacebookAI_xlm_roberta_base.png", dpi=500, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Example confusion matrix data
confusion_matrix = np.array([
    [98, 29, 56],
    [45, 67, 53],
    [52, 39, 134]
])

# Normalizing the confusion matrix
confusion_matrix_normalized = confusion_matrix / confusion_matrix.sum(axis=1)[:, np.newaxis]

# Labels for the axes
labels = ['positive', 'neutral', 'negative']

# Plotting the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_matrix_normalized, annot=True, fmt=".2f", cmap="Blues", xticklabels=labels, yticklabels=labels)

# Adding titles and labels
plt.title("Confusion Matrix")
plt.xlabel("Predicted Sign")
plt.ylabel("True Sign")

# Save the figure
plt.savefig("distilbert_distilbert_base_uncased.png", dpi=500, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Example confusion matrix data
confusion_matrix = np.array([
    [108, 36, 39],
    [32, 106, 27],
    [40, 31, 154]
])

# Normalizing the confusion matrix
confusion_matrix_normalized = confusion_matrix / confusion_matrix.sum(axis=1)[:, np.newaxis]

# Labels for the axes
labels = ['positive', 'neutral', 'negative']

# Plotting the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_matrix_normalized, annot=True, fmt=".2f", cmap="Blues", xticklabels=labels, yticklabels=labels)

# Adding titles and labels
plt.title("Confusion Matrix")
plt.xlabel("Predicted Sign")
plt.ylabel("True Sign")

# Save the figure
plt.savefig("google_bert_bert_base_multilingual_cased.png", dpi=500, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Example confusion matrix data
confusion_matrix = np.array([
    [119, 27, 37],
    [31, 97, 37],
    [36, 31, 158]
])

# Normalizing the confusion matrix
confusion_matrix_normalized = confusion_matrix / confusion_matrix.sum(axis=1)[:, np.newaxis]

# Labels for the axes
labels = ['positive', 'neutral', 'negative']

# Plotting the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_matrix_normalized, annot=True, fmt=".2f", cmap="Blues", xticklabels=labels, yticklabels=labels)

# Adding titles and labels
plt.title("Confusion Matrix")
plt.xlabel("Predicted Sign")
plt.ylabel("True Sign")

# Save the figure
plt.savefig("sagorsarker_bangla_bert_base.png", dpi=500, bbox_inches='tight')
plt.show()
